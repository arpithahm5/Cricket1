# %%
import numpy as np
import pandas as pd

# %%
#read CSV file containing data

df = pd.read_csv('deliveries.csv')

# %%
#to check all the columns in the dataframe

df.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'wide_runs', 'bye_runs',
#        'legbye_runs', 'noball_runs', 'batsman_runs', 'extra_runs', 'total',
#        'player_dismissed', 'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
#to find number of rows in the data

len(df)
# Out:
# 929563

# %%
#to find count of different number of innings 

df['inning'].value_counts()
# Out:
# 1    503918
# 2    425645
# Name: inning, dtype: int64

# %%
df1 = (df[df['inning'] == 1])

# %%
df1.head(20)
# Out:
#     match_id  inning batting_team bowling_team  over  ball    batsman  \
# 0          1       1    Australia     Pakistan     1     1  DA Warner
# 1          1       1    Australia     Pakistan     1     2  DA Warner
# 2          1       1    Australia     Pakistan     1     3  DA Warner
# 3          1       1    Australia     Pakistan     1     4  DA Warner
# 4          1       1    Australia     Pakistan     1     5  DA Warner
# 5          1       1    Australia     Pakistan     1     6  DA Warner
# 6          1       1    Australia     Pakistan     1     7  DA Warner
# 7          1       1    Australia     Pakistan     2     1    TM Head
# 8          1       1    Australia     Pakistan     2     2    TM Head
# 9          1       1    Australia     Pakistan     2     3  DA Warner
# 10         1       1    Australia     Pakistan     2     4  DA Warner
# 11         1       1    Australia     Pakistan     2     5  DA Warner
# ...

# %%
df1.batting_team.value_counts()
# Out:
# Australia                   64145
# Sri Lanka                   61096
# India                       49694
# England                     47572
# Pakistan                    44898
# South Africa                44797
# New Zealand                 43456
# West Indies                 36716
# Bangladesh                  30396
# Zimbabwe                    23312
# Ireland                     12720
# Afghanistan                 12266
# Scotland                     8530
# United Arab Emirates         3989
# Kenya                        3192
# Canada                       2722
# Netherlands                  2656
# Bermuda                      2207
# United States of America     2180
# Papua New Guinea             2128
# Namibia                      1378
# Hong Kong                    1189
# Nepal                        1130
# Asia XI                       934
# Oman                          615
# Name: batting_team, dtype: int64

# %%
len(df1.batting_team.value_counts())

# %%
df1.bowling_team.value_counts()
# Out:
# India                       61661
# England                     50792
# South Africa                46364
# Pakistan                    46359
# Sri Lanka                   45697
# West Indies                 44634
# Australia                   43970
# New Zealand                 40101
# Bangladesh                  33057
# Zimbabwe                    28654
# Ireland                     17914
# Afghanistan                  9232
# Scotland                     5646
# United Arab Emirates         5533
# Canada                       4876
# Kenya                        4592
# Netherlands                  3741
# Oman                         2695
# Papua New Guinea             2109
# Hong Kong                    1926
# United States of America     1172
# Bermuda                       948
# Africa XI                     934
# Nepal                         683
# Namibia                       628
# Name: bowling_team, dtype: int64

# %%
len(df1.bowling_team.value_counts())
# Out:
# 25

# %%
#to get data of first innings where batting team is Australia and Bowling team is Pakistan

batsman = df1['batting_team'] == 'Australia'
bowler = df1['bowling_team'] == 'Pakistan'
match_id = df1['match_id'] == 1

first_match = df1[batsman & bowler & match_id]

# %%
first_match
# Out:
#      match_id  inning batting_team bowling_team  over  ball    batsman  \
# 0           1       1    Australia     Pakistan     1     1  DA Warner
# 1           1       1    Australia     Pakistan     1     2  DA Warner
# 2           1       1    Australia     Pakistan     1     3  DA Warner
# 3           1       1    Australia     Pakistan     1     4  DA Warner
# 4           1       1    Australia     Pakistan     1     5  DA Warner
# ..        ...     ...          ...          ...   ...   ...        ...
# 305         1       1    Australia     Pakistan    50     2    MS Wade
# 306         1       1    Australia     Pakistan    50     3    MS Wade
# 307         1       1    Australia     Pakistan    50     4    MS Wade
# 308         1       1    Australia     Pakistan    50     5    MS Wade
# 309         1       1    Australia     Pakistan    50     6    MS Wade
#
#     non_striker         bowler  wide_runs  bye_runs  legbye_runs  noball_runs  \
# ...
